# %% [markdown]
# <a href="https://colab.research.google.com/github/NavdeeepSinghh/Project-Neerakshak-/blob/main/Microplastic_detector_using_YOLOV8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install YOLO
# uncomment the first line if YOLO are not installed

# %%
# !pip install ultralytics
from ultralytics import YOLO
from google.colab import files
import locale
# Play an audio beep. Any audio URL will do.
from google.colab import output

# %% [markdown]
# # Get the data via Roboflow
# uncomment the first line if Roboflow are not installed

# %%
# !pip install roboflow
# from roboflow import Roboflow
# rf = Roboflow(api_key="Dlwgwe3psTHRPIuQlsbV")
# project = rf.workspace("panats-mp-project").project("microplastic-dataset")
# dataset = project.version(19).download("yolov8")

# %% [markdown]
# you have to change in the microplastic dataset -> data.yaml the path train & valid.
#
# copy paste these lines:
#
# ```
# train: /content/Microplastic-Dataset-19/train/images
# val: /content/Microplastic-Dataset-19/valid/images
#
# ```

# %% [markdown]
# # Modeling
# yolov8n is the smallest model, you can use yolov8s, yolov8l, yolov8x for better results you need to have more than 15GB of GPU RAM.

# %%
# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# %% [markdown]
# # Train with tuned hyperparameters

# %%
# Use the model
# model.train(data="/content/Microplastic-Dataset-19/data.yaml", imgsz=1280, batch=4, epochs=1, cfg="best_hyperparameters.yaml", workers=8, device=0, nbs=8, patience=20)  # train the model

# %% [markdown]
# # Hyperparameter tuning

# %%
res = model.tune(data="/content/Microplastic-Dataset-19/data.yaml", imgsz=1280, batch=4, epochs=30, iterations=50, plots=False, save=False)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 1/50 iterations complete ✅ (1333.81s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.34068 observed at iteration 1
# ...

# %% [markdown]
# Download the "v1-runs.zip" to analyse all your result.

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# export the folders runs
# !zip -r runs.zip /content/runs

# %%
files.download("/content/runs.zip")
